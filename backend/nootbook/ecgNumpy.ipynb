# %%
import numpy as np

# %%
X1 = np.load("ecg_chunks/chunk_0.npy")
# X2 = np.load("ecg_chunks/chunk_130000.npy")

# %%
X1.shape
# Out:
# (1000, 5000, 12)

# %%
X
# Out:
# array([[[-0.155,  0.01 ,  0.15 , ...,  0.04 ,  0.08 ,  0.02 ],
#         [-0.17 ,  0.01 ,  0.165, ...,  0.03 ,  0.08 ,  0.02 ],
#         [-0.17 ,  0.   ,  0.155, ...,  0.025,  0.08 ,  0.01 ],
#         ...,
#         [-0.045,  0.01 ,  0.04 , ..., -0.02 , -0.02 , -0.2  ],
#         [-0.055,  0.   ,  0.04 , ..., -0.02 , -0.02 , -0.2  ],
#         [-0.075, -0.01 ,  0.05 , ..., -0.02 , -0.02 , -0.2  ]],
#
#        [[ 0.045,  0.   , -0.07 , ..., -0.02 ,  0.   , -0.01 ],
#         [ 0.045,  0.   , -0.07 , ..., -0.015,  0.   , -0.01 ],
#         [ 0.04 , -0.01 , -0.075, ..., -0.015,  0.   , -0.01 ],
#         ...,
#         [ 0.16 ,  0.17 , -0.015, ...,  0.3  ,  0.155,  0.14 ],
#         [ 0.155,  0.155, -0.025, ...,  0.26 ,  0.14 ,  0.125],
#         [ 0.14 ,  0.14 , -0.03 , ...,  0.22 ,  0.12 ,  0.11 ]],
#
#        [[ 0.02 ,  0.06 ,  0.04 , ...,  0.035,  0.42 , -0.28 ],
#         [ 0.   ,  0.075,  0.075, ...,  0.045,  0.41 , -0.295],
# ...

# %%
Xfloat = np.float16(X)

# %%
Xfloat.nbytes
# Out:
# 120000000

# %%
Xfloat
# Out:
# array([[[-0.155,  0.01 ,  0.15 , ...,  0.04 ,  0.08 ,  0.02 ],
#         [-0.17 ,  0.01 ,  0.165, ...,  0.03 ,  0.08 ,  0.02 ],
#         [-0.17 ,  0.   ,  0.155, ...,  0.025,  0.08 ,  0.01 ],
#         ...,
#         [-0.045,  0.01 ,  0.04 , ..., -0.02 , -0.02 , -0.2  ],
#         [-0.055,  0.   ,  0.04 , ..., -0.02 , -0.02 , -0.2  ],
#         [-0.075, -0.01 ,  0.05 , ..., -0.02 , -0.02 , -0.2  ]],
#
#        [[ 0.045,  0.   , -0.07 , ..., -0.02 ,  0.   , -0.01 ],
#         [ 0.045,  0.   , -0.07 , ..., -0.015,  0.   , -0.01 ],
#         [ 0.04 , -0.01 , -0.075, ..., -0.015,  0.   , -0.01 ],
#         ...,
#         [ 0.16 ,  0.17 , -0.015, ...,  0.3  ,  0.155,  0.14 ],
#         [ 0.155,  0.155, -0.025, ...,  0.26 ,  0.14 ,  0.125],
#         [ 0.14 ,  0.14 , -0.03 , ...,  0.22 ,  0.12 ,  0.11 ]],
#
#        [[ 0.02 ,  0.06 ,  0.04 , ...,  0.035,  0.42 , -0.28 ],
#         [ 0.   ,  0.075,  0.075, ...,  0.045,  0.41 , -0.295],
# ...
